# %%
# baseball_predictor_harness.ipynb
# Alexis Perumal, Venkat Pinnika, Young You, 1/5/2020
#
# Calls one or more predictor algorithms to predict baseball game outcomes across a range
# of dates. This harness captures the outcomes in a Pandas DF and writes it out to a file
# for further analysis of effectiveness and hyperparameter tuning.

# %%
# Modules
import os
import csv
import pprint
import pandas as pd
import pprint
import datetime

import net_points_predictor as npp

# %%
outcomes_df = pd.DataFrame(columns=['Season', 'Lookback', 'Num Games',
                                  'Num Correct', '% Correct',
                                   'Timestamp', 'Run Duration',
                                   'Comment'])
outcomes_df
# Out:
# Empty DataFrame
# Columns: [Season, Lookback, Num Games, Num Correct, % Correct, Timestamp, Run Duration, Comment]
# Index: []

# %%
#for n in [10, 25, 50, 100, 200, 300]:
for n in [5, 10, 25, 50, 100]:
    for season in range(2011, 2018):
#         n = 10
        start_time = datetime.datetime.now()
        num_games, num_correct, percent_correct = npp.net_points_predictor(n, season)
        end_time = datetime.datetime.now()
    #     num_games = 2
    #     num_correct = 1
    #     percent_correct = 50.0

        new_row = pd.Series({'Season':season,
                               'Lookback':n,
                               'Num Games':num_games,
                               'Num Correct':num_correct,
                               '% Correct':percent_correct,
                               'Timestamp':start_time,
                               'Run Duration':end_time - start_time,
                               'Comment':''})
        outcomes_df = outcomes_df.append(new_row, ignore_index=True)
    
outcomes_df
# Out:
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2011 season: 2011-03-31 - 2011-09-28, with 10 day lookback.
#   2020-01-06 00:01:21.387830: Starting build of net runs rolling average tables.
#   2020-01-06 00:02:14.000900: Net point tables calculated in 0:00:52.613070 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:02:14.106403: Predictions calculated in 0:00:00.102087 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2012 season: 2012-03-28 - 2012-10-03, with 10 day lookback.
#   2020-01-06 00:02:14.991647: Starting build of net runs rolling average tables.
#   2020-01-06 00:03:08.604051: Net point tables calculated in 0:00:53.612404 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:03:08.709266: Predictions calculated in 0:00:00.102065 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2013 season: 2013-03-31 - 2013-09-30, with 10 day lookback.
#   2020-01-06 00:03:09.602404: Starting build of net runs rolling average tables.
#   2020-01-06 00:04:02.301763: Net point tables calculated in 0:00:52.699359 hr/min/sec.
#   Results table of length 2431
#   2020-01-06 00:04:02.402131: Predictions calculated in 0:00:00.097136 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2014 season: 2014-03-22 - 2014-09-28, with 10 day lookback.
#   2020-01-06 00:04:03.209419: Starting build of net runs rolling average tables.
#   2020-01-06 00:04:56.296406: Net point tables calculated in 0:00:53.086987 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:04:56.400087: Predictions calculated in 0:00:00.101361 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2015 season: 2015-04-05 - 2015-10-04, with 10 day lookback.
#   2020-01-06 00:04:57.264142: Starting build of net runs rolling average tables.
#   2020-01-06 00:05:49.803367: Net point tables calculated in 0:00:52.539225 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:05:49.908850: Predictions calculated in 0:00:00.102176 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2016 season: 2016-04-03 - 2016-10-02, with 10 day lookback.
#   2020-01-06 00:05:50.796289: Starting build of net runs rolling average tables.
#   2020-01-06 00:06:44.251502: Net point tables calculated in 0:00:53.455213 hr/min/sec.
#   Results table of length 2428
#   2020-01-06 00:06:44.353061: Predictions calculated in 0:00:00.098280 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2017 season: 2017-04-02 - 2017-10-01, with 10 day lookback.
#   2020-01-06 00:06:45.170893: Starting build of net runs rolling average tables.
#   2020-01-06 00:07:37.577190: Net point tables calculated in 0:00:52.406297 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:07:37.674631: Predictions calculated in 0:00:00.093897 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2011 season: 2011-03-31 - 2011-09-28, with 25 day lookback.
#   2020-01-06 00:07:38.492832: Starting build of net runs rolling average tables.
#   2020-01-06 00:08:35.669331: Net point tables calculated in 0:00:57.176499 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:08:35.782141: Predictions calculated in 0:00:00.107895 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2012 season: 2012-03-28 - 2012-10-03, with 25 day lookback.
#   2020-01-06 00:08:36.766827: Starting build of net runs rolling average tables.
#   2020-01-06 00:09:37.727892: Net point tables calculated in 0:01:00.961065 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:09:37.835036: Predictions calculated in 0:00:00.101853 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2013 season: 2013-03-31 - 2013-09-30, with 25 day lookback.
#   2020-01-06 00:09:38.731989: Starting build of net runs rolling average tables.
#   2020-01-06 00:10:38.960165: Net point tables calculated in 0:01:00.228176 hr/min/sec.
#   Results table of length 2431
#   2020-01-06 00:10:39.071066: Predictions calculated in 0:00:00.106823 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2014 season: 2014-03-22 - 2014-09-28, with 25 day lookback.
#   2020-01-06 00:10:40.042622: Starting build of net runs rolling average tables.
#   2020-01-06 00:11:37.971686: Net point tables calculated in 0:00:57.929064 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:11:38.081753: Predictions calculated in 0:00:00.103319 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2015 season: 2015-04-05 - 2015-10-04, with 25 day lookback.
#   2020-01-06 00:11:38.964800: Starting build of net runs rolling average tables.
#   2020-01-06 00:12:40.835338: Net point tables calculated in 0:01:01.870538 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:12:40.944228: Predictions calculated in 0:00:00.104431 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2016 season: 2016-04-03 - 2016-10-02, with 25 day lookback.
#   2020-01-06 00:12:41.828685: Starting build of net runs rolling average tables.
#   2020-01-06 00:13:38.972287: Net point tables calculated in 0:00:57.143602 hr/min/sec.
#   Results table of length 2428
#   2020-01-06 00:13:39.083102: Predictions calculated in 0:00:00.104746 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2017 season: 2017-04-02 - 2017-10-01, with 25 day lookback.
#   2020-01-06 00:13:39.956588: Starting build of net runs rolling average tables.
#   2020-01-06 00:14:38.211511: Net point tables calculated in 0:00:58.254923 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:14:38.325725: Predictions calculated in 0:00:00.109788 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2011 season: 2011-03-31 - 2011-09-28, with 50 day lookback.
#   2020-01-06 00:14:39.294550: Starting build of net runs rolling average tables.
#   2020-01-06 00:15:44.314738: Net point tables calculated in 0:01:05.020188 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:15:44.426049: Predictions calculated in 0:00:00.107756 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2012 season: 2012-03-28 - 2012-10-03, with 50 day lookback.
#   2020-01-06 00:15:45.362356: Starting build of net runs rolling average tables.
#   2020-01-06 00:16:49.412679: Net point tables calculated in 0:01:04.050323 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:16:49.519750: Predictions calculated in 0:00:00.102804 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2013 season: 2013-03-31 - 2013-09-30, with 50 day lookback.
#   2020-01-06 00:16:50.392027: Starting build of net runs rolling average tables.
#   2020-01-06 00:17:54.235046: Net point tables calculated in 0:01:03.843019 hr/min/sec.
#   Results table of length 2431
#   2020-01-06 00:17:54.334251: Predictions calculated in 0:00:00.095110 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2014 season: 2014-03-22 - 2014-09-28, with 50 day lookback.
#   2020-01-06 00:17:55.157609: Starting build of net runs rolling average tables.
#   2020-01-06 00:19:00.184120: Net point tables calculated in 0:01:05.026511 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:19:00.292805: Predictions calculated in 0:00:00.104360 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2015 season: 2015-04-05 - 2015-10-04, with 50 day lookback.
#   2020-01-06 00:19:01.114226: Starting build of net runs rolling average tables.
#   2020-01-06 00:20:04.504666: Net point tables calculated in 0:01:03.390440 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:20:04.615141: Predictions calculated in 0:00:00.105599 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2016 season: 2016-04-03 - 2016-10-02, with 50 day lookback.
#   2020-01-06 00:20:05.486815: Starting build of net runs rolling average tables.
#   2020-01-06 00:21:08.879393: Net point tables calculated in 0:01:03.392578 hr/min/sec.
#   Results table of length 2428
#   2020-01-06 00:21:08.986989: Predictions calculated in 0:00:00.103639 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2017 season: 2017-04-02 - 2017-10-01, with 50 day lookback.
#   2020-01-06 00:21:09.872733: Starting build of net runs rolling average tables.
#   2020-01-06 00:22:13.781056: Net point tables calculated in 0:01:03.908323 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:22:13.880704: Predictions calculated in 0:00:00.096442 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2011 season: 2011-03-31 - 2011-09-28, with 100 day lookback.
#   2020-01-06 00:22:14.706566: Starting build of net runs rolling average tables.
#   2020-01-06 00:23:32.994289: Net point tables calculated in 0:01:18.287723 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:23:33.103543: Predictions calculated in 0:00:00.105225 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2012 season: 2012-03-28 - 2012-10-03, with 100 day lookback.
#   2020-01-06 00:23:33.964565: Starting build of net runs rolling average tables.
#   2020-01-06 00:24:57.362472: Net point tables calculated in 0:01:23.397907 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:24:57.461812: Predictions calculated in 0:00:00.094984 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2013 season: 2013-03-31 - 2013-09-30, with 100 day lookback.
#   2020-01-06 00:24:58.354104: Starting build of net runs rolling average tables.
#   2020-01-06 00:26:19.471425: Net point tables calculated in 0:01:21.117321 hr/min/sec.
#   Results table of length 2431
#   2020-01-06 00:26:19.587483: Predictions calculated in 0:00:00.112073 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2014 season: 2014-03-22 - 2014-09-28, with 100 day lookback.
#   2020-01-06 00:26:20.520086: Starting build of net runs rolling average tables.
#   2020-01-06 00:27:43.130239: Net point tables calculated in 0:01:22.610153 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:27:43.237736: Predictions calculated in 0:00:00.102861 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2015 season: 2015-04-05 - 2015-10-04, with 100 day lookback.
#   2020-01-06 00:27:44.095761: Starting build of net runs rolling average tables.
#   2020-01-06 00:29:05.971881: Net point tables calculated in 0:01:21.876120 hr/min/sec.
#   Results table of length 2429
#   2020-01-06 00:29:06.090968: Predictions calculated in 0:00:00.114312 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2016 season: 2016-04-03 - 2016-10-02, with 100 day lookback.
#   2020-01-06 00:29:07.031333: Starting build of net runs rolling average tables.
#   2020-01-06 00:30:29.050747: Net point tables calculated in 0:01:22.019414 hr/min/sec.
#   Results table of length 2428
#   2020-01-06 00:30:29.153843: Predictions calculated in 0:00:00.098611 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2017 season: 2017-04-02 - 2017-10-01, with 100 day lookback.
#   2020-01-06 00:30:29.970444: Starting build of net runs rolling average tables.
#   2020-01-06 00:31:51.762871: Net point tables calculated in 0:01:21.792427 hr/min/sec.
#   Results table of length 2430
#   2020-01-06 00:31:51.878975: Predictions calculated in 0:00:00.111118 hr/min/sec.
#
# Dataset loaded with 19437 games, 10 columns, 2010-04-04 - 2017-10-01
#   Analyzing 2011 season: 2011-03-31 - 2011-09-28, with 200 day lookback.
#   2020-01-06 00:31:52.816112: Starting build of net runs rolling average tables.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f489bef7bd88> in <module>
#       3 #         n = 10
#       4         start_time = datetime.datetime.now()
# ----> 5         num_games, num_correct, percent_correct = npp.net_points_predictor(n, season)
#       6         end_time = datetime.datetime.now()
#       7     #     num_games = 2
#
# ~/OneDrive/Personal/UCSD_Data_Science_Bootcamp/Homework/2019-12-18_Proj1_Baseball-Predictor/baseball-predictor/alexis/net_points_predictor.py in net_points_predictor(lookback_n, season)
#     205 #     print(f"Starting games_df length: {len(games_df)}")
#     206     (v_ra_np_df, h_ra_np_df) = build_netpoints_dfs(games_df, start_date, end_date, \
# --> 207                                                   lookback_n, gamedays)
#     208 #     print(f"Ending games_df length: {len(games_df)}")
#     209
#
# ~/OneDrive/Personal/UCSD_Data_Science_Bootcamp/Homework/2019-12-18_Proj1_Baseball-Predictor/baseball-predictor/alexis/net_points_predictor.py in build_netpoints_dfs(games_df, start_date, end_date, lookback_n, gdays)
#     101
#     102     # Determine lookback dates for first game day.
# --> 103     lookback_start_day = gamedays_offset(gdays, start_date, -lookback_n)
#     104     lookback_end_day = gamedays_offset(gdays, start_date, -1)
#     105
#
# ~/OneDrive/Personal/UCSD_Data_Science_Bootcamp/Homework/2019-12-18_Proj1_Baseball-Predictor/baseball-predictor/alexis/net_points_predictor.py in gamedays_offset(gamedays, base_date, n)
#      88     base_date_index = gamedays[gamedays==base_date].index[0]
#      89     if ((n + base_date_index) < 0) or n + base_date_index >= len(gamedays):
# ---> 90         raise ValueError(f"Attempting to calculate a game date outside the dataset.")
#      91         return(0)  # Out of range
#      92     else:
#
# ValueError: Attempting to calculate a game date outside the dataset.

# %%
path = "output/" + str(datetime.datetime.now()) + "_output.csv"
outcomes_df.to_csv(path_or_buf=path)

# %%
outcomes_df
# Out:
